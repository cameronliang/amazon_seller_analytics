# %%
import numpy as np
import pandas as pd 
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = '../original_data/monthly/'

file_lists = os.listdir(path)
frames = []
for fname in file_lists:
    frames.append(pd.read_csv(path + fname))

# %%
df = pd.concat(frames)

# %%
df.head()
# Out:
#   (Parent) ASIN                                              Title  Sessions  \
# 0    B00CWU48VI  Isolation Vibration m6 Rubber Mount Replacemen...        69
# 1    B007S1V7MY  90-93 Mazda Miata MX5 MX-5 Intake Mass Air Flo...        82
# 2    B0058W7YAO  HPS Stainless Steel T-Bolt Clamp 5.2" - 5.6" (...        40
# 3    B00AZM8UZ0  Black 3.5" Rubber Coupler hose for shortram co...       146
# 4    B00CWU4IJ0  Isolation Vibration m8 Rubber Mount Replacemen...        11
#
#   Session Percentage Page Views Page Views Percentage Buy Box Percentage  \
# 0              0.17%         94                 0.19%                95%
# 1              0.20%        101                 0.20%                85%
# 2              0.10%         48                 0.10%                98%
# 3              0.35%        172                 0.34%                88%
# 4              0.03%         12                 0.02%                92%
#
#    Units Ordered Unit Session Percentage Ordered Product Sales  \
# 0             13                  18.84%               $108.20
# 1              4                   4.88%                $46.00
# 2              3                   7.50%                $17.44
# 3              3                   2.05%                $12.06
# 4              4                  36.36%                $34.14
#
#    Total Order Items
# 0                 11
# 1                  4
# 2                  3
# 3                  3
# 4                  3

# %%
a = df.loc[df['(Parent) ASIN'] == 'B00CWU48VI']
a.to_csv('result.csv',index=True)
