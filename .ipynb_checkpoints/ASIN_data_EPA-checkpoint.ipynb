# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fname = '../original_data/Revised By ASIN-Datail Page Sales and Traffic by Parent Item.csv'
df = pd.read_csv(fname)
df = df.replace(',','',regex=True)
df.head()
# Out:
#   (Parent) ASIN                                              Title Sessions  \
# 0    B00CWU48VI  Isolation Vibration m6 Rubber Mount Replacemen...      764
# 1    B00CWU4DTA  Isolation Vibration m6 Rubber Mount Replacemen...      973
# 2    B005B00EVY  HPS HTHH-062-BLK Silicone High Temperature Rei...     3038
# 3    B004NYCI2C  HPS HTSC-200-L4-BLK Silicone High Temperature ...     2351
# 4    B00ATI059E  Black 3" Rubber Coupler hose for shortram cold...      424
#
#   Session Percentage Page Views Page Views Percentage Buy Box Percentage  \
# 0              0.16%       1164                 0.18%                83%
# 1              0.20%       1585                 0.25%                44%
# 2              0.64%       4166                 0.66%                15%
# 3              0.49%       3418                 0.54%                 9%
# 4              0.09%        604                 0.10%                88%
#
#    Units Ordered Unit Session Percentage Ordered Product Sales  \
# 0            177                  23.17%              $1514.48
# 1             70                   7.19%               $261.89
# 2             47                   1.55%               $515.95
# 3             58                   2.47%               $648.23
# 4             51                  12.03%               $134.41
#
#    Total Order Items
# 0                149
# 1                 62
# 2                 33
# 3                 30
# 4                 28

# %%
df.tail()
# Out:
#       (Parent) ASIN                                              Title  \
# 10436    B07QPGN4N3              HPS Blue Shortram Air Intake Kit Cool
# 10437    B07QT67F58                                                NaN
# 10438    B07QWB925K  HPS (SSTC-83-91) 83mm - 91mm Stainless Steel T...
# 10439    B07R47QWWV  HPS 27-509BL Blue Short Ram Air Intake Kit (No...
# 10440    B07R8FCSF8     HPS 27-525BL Blue Shortram Air Intake Kit Cool
#
#       Sessions Session Percentage Page Views Page Views Percentage  \
# 10436       16              0.00%         20                 0.00%
# 10437      221              0.05%        336                 0.05%
# 10438     2203              0.46%       3281                 0.52%
# 10439       52              0.01%         78                 0.01%
# 10440       23              0.00%         32                 0.01%
#
#       Buy Box Percentage  Units Ordered Unit Session Percentage  \
# 10436                 0%              0                   0.00%
# 10437                 0%              0                   0.00%
# 10438                 0%              0                   0.00%
# 10439                18%              0                   0.00%
# 10440                41%              0                   0.00%
#
#       Ordered Product Sales  Total Order Items
# 10436                 $0.00                  0
# 10437                 $0.00                  0
# 10438                 $0.00                  0
# 10439                 $0.00                  0
# 10440                 $0.00                  0

# %%
df['Buy Box Percentage'] = df['Buy Box Percentage'].str.rstrip('%').astype('float') /100.0
df['Page Views Percentage'] = df['Page Views Percentage'].str.rstrip('%').astype('float') /100.0

# %%
df['Ordered Product Sales'] = df['Ordered Product Sales'].str.replace('$','').astype('float')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-fd739277d6e6> in <module>
# ----> 1 df['Ordered Product Sales'] = df['Ordered Product Sales'].str.replace('$','').astype('float')
#
# ~/opt/anaconda3/envs/insight/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5268             or name in self._accessors
#    5269         ):
# -> 5270             return object.__getattribute__(self, name)
#    5271         else:
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/opt/anaconda3/envs/insight/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # http://www.pydanny.com/cached-property.html
#
# ~/opt/anaconda3/envs/insight/lib/python3.7/site-packages/pandas/core/strings.py in __init__(self, data)
#    2039
#    2040     def __init__(self, data):
# -> 2041         self._inferred_dtype = self._validate(data)
#    2042         self._is_categorical = is_categorical_dtype(data)
#    2043         self._is_string = data.dtype.name == "string"
#
# ~/opt/anaconda3/envs/insight/lib/python3.7/site-packages/pandas/core/strings.py in _validate(data)
#    2096
#    2097         if inferred_dtype not in allowed_types:
# -> 2098             raise AttributeError("Can only use .str accessor with string values!")
#    2099         return inferred_dtype
#    2100
#
# AttributeError: Can only use .str accessor with string values!

# %%
plt.plot(df['Page Views Percentage'],df['Ordered Product Sales'],'o')
#plt.yscale('log')
#plt.xscale('log')
#plt.hist(df['Buy Box Percentage'])
